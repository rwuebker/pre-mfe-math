# %%
import numpy as np

# %%
payments = [2061]
discounted_payments = [2061]
discount_rate = (1.01)**76
init_discount_rate = (1.01)**47
for i in range(0,300):
    prev_payment = payments[i]
    next_payment = (prev_payment + 76)
    payments.append(next_payment)
    
    discounted_payment = next_payment / discount_rate**(i+1)
    discounted_payments.append(discounted_payment)
    
total = np.sum(discounted_payments) / init_discount_rate
total
# Out:
# 2512.917752255293

# %%
print(discounted_payments)
# Out:
# [2061, 1003.1828861556118, 487.6773652238789, 236.79502308945004, 114.85066526226254, 55.64751074589259, 26.936227454790586, 13.026617597217632, 6.294385154459339, 3.0389438897652354, 1.4660845307212265, 0.7067731018648183, 0.34048816384733904, 0.16392308813594617, 0.07886936004919914, 0.03792447364658925, 0.018225771523114102, 0.008754243578067986, 0.004202697681888256, 0.002016620975772222, 0.0009671997406420882, 0.00046367363618639523, 0.00022218821775215909, 0.00010642645605198006, 5.095716330512162e-05, 2.4389037158853336e-05, 1.1668745153375981e-05, 5.580841745663563e-06, 2.668252659066328e-06, 1.2752966490986354e-06, 6.093370159581718e-07, 2.910521202374601e-07, 1.3898098304036883e-07, 6.634614769720105e-08, 3.1663277269462246e-08, 1.510705250452991e-08, 7.20594676122143e-09, 3.4363179016028727e-09, 1.6382869413343798e-09, 7.808797744810199e-10, 3.7211658295684976e-10, 1.7728723154046937e-10, 8.444662293872295e-11, 4.0215752418266495e-11, 1.9147927266029148e-11, 9.115100584663
# ...

# %%
v = 76 * (1.01)**76 / (((1.01)**76 - 1)*((1.01)**76 - 1))
v
# Out:
# 126.73956530340597

# %%
f = 2061 * 1 / (1 - (1/(1.01)**76))
f
# Out:
# 3884.5391785155925

# %%
(f+v)/init_discount_rate
# Out:
# 2512.9177522552936

# %%
2213 / (1.01)**152
# Out:
# 487.677365223879

# %%
76*2
# Out:
# 152
